# %%
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.naive_bayes import GaussianNB
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score

# %%
# Load data
df = pd.read_excel("dataset.xlsx")
X = df[['Nilai_1', 'Nilai_2', 'Nilai_3']]
y = df['Label']

# %%
# Encode label
le = LabelEncoder()
y = le.fit_transform(y)

# %%
# K-Fold
kf = KFold(n_splits=5, shuffle=False)

model = GaussianNB()
akurasi = []

# %%
fold = 1
for train_index, test_index in kf.split(X):
    X_train, X_test = X.iloc[train_index], X.iloc[test_index]
    y_train, y_test = y[train_index], y[test_index]
    
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    acc = accuracy_score(y_test, y_pred)
    akurasi.append(acc)
    
    print(f"Fold {fold} Akurasi: {acc*100:.2f}%")
    fold += 1

print("\nAkurasi Rata-rata:", sum(akurasi)/len(akurasi)*100, "%")
# Out:
# Fold 1 Akurasi: 80.00%
# Fold 2 Akurasi: 100.00%
# Fold 3 Akurasi: 90.00%
# Fold 4 Akurasi: 90.00%
# Fold 5 Akurasi: 90.00%
#
# Akurasi Rata-rata: 90.0 %
